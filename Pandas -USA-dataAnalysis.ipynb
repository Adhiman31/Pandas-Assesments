# %%
import pandas as pd
import csvkit as cs
import pymongo
import json
import mysql.connector as con
import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)

# %%
orders_df = pd.read_excel(r'C:\Users\anile\Documents\Superstore_USA.xlsx',sheet_name='Orders')

# %%
orders_df
# Out:
#       Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0      18606  Not Specified      0.01        2.88           0.50            2
# 1      20847           High      0.01        2.84           0.93            3
# 2      23086  Not Specified      0.03        6.68           6.15            3
# 3      23087  Not Specified      0.01        5.68           3.60            3
# 4      23088  Not Specified      0.00      205.99           2.50            3
# ...      ...            ...       ...         ...            ...          ...
# 9421   20275       Critical      0.06       35.89          14.72         3402
# 9422   20276       Critical      0.00        3.34           7.49         3402
# 9423   24491  Not Specified      0.08      550.98          45.70         3402
# 9424   25914           High      0.10      105.98          13.99         3403
# 9425   24492  Not Specified      0.09        7.78           2.50         3403
#
# ...

# %%
return_df = pd.read_excel(r'C:\Users\anile\Documents\Superstore_USA.xlsx',sheet_name='Returns')

# %%
return_df
# Out:
#       Order ID    Status
# 0           65  Returned
# 1          612  Returned
# 2          614  Returned
# 3          678  Returned
# 4          710  Returned
# ...        ...       ...
# 1629    182681  Returned
# 1630    182683  Returned
# 1631    182750  Returned
# 1632    182781  Returned
# 1633    182906  Returned
#
# [1634 rows x 2 columns]

# %%
Users_df = pd.read_excel(r'C:\Users\anile\Documents\Superstore_USA.xlsx',sheet_name='Users')

# %%
Users_df
# Out:
#     Region  Manager
# 0  Central    Chris
# 1     East     Erin
# 2    South      Sam
# 3     West  William

# %%
#Converting the data into csv file in order to load into sql workbench

# %%
orders_df.to_csv(r'C:\Users\anile\Returns.csv')

# %%
return_df.to_csv(r'C:\Users\anile\Orders.csv')

# %%
Users_df.to_csv(r'C:\Users\anile\Users.csv')

# %%
# uploading data in to sql workbench

# %%
# !csvsql --db mysql://root:Akd!23456@localhost:3306/usanalysis --insert Orders.csv
# Out:
# c:\users\anile\anaconda3\lib\site-packages\win32\lib\pywintypes.py:2: DeprecationWarning: the imp module is deprecated in favour of importlib; see the module's documentation for alternative uses
# c:\users\anile\anaconda3\lib\site-packages\agate\utils.py:285: UnnamedColumnWarning: Column 0 has no name. Using "a".
# C:\Users\anile\anaconda3\lib\site-packages\IPython\utils\_process_win32.py:145: ResourceWarning: unclosed file <_io.BufferedWriter name=4>
# C:\Users\anile\anaconda3\lib\site-packages\IPython\utils\_process_win32.py:145: ResourceWarning: unclosed file <_io.BufferedReader name=5>
# C:\Users\anile\anaconda3\lib\site-packages\IPython\utils\_process_win32.py:145: ResourceWarning: unclosed file <_io.BufferedReader name=6>

# %%
# !csvsql --db mysql://root:Akd!23456@localhost:3306/usanalysis --insert Returns.csv
# Out:
# c:\users\anile\anaconda3\lib\site-packages\win32\lib\pywintypes.py:2: DeprecationWarning: the imp module is deprecated in favour of importlib; see the module's documentation for alternative uses
# c:\users\anile\anaconda3\lib\site-packages\agate\table\from_csv.py:74: RuntimeWarning: Error sniffing CSV dialect: Could not determine delimiter
# c:\users\anile\anaconda3\lib\site-packages\agate\utils.py:285: UnnamedColumnWarning: Column 0 has no name. Using "a".
# C:\Users\anile\anaconda3\lib\site-packages\IPython\utils\_process_win32.py:145: ResourceWarning: unclosed file <_io.BufferedWriter name=4>
# C:\Users\anile\anaconda3\lib\site-packages\IPython\utils\_process_win32.py:145: ResourceWarning: unclosed file <_io.BufferedReader name=5>
# C:\Users\anile\anaconda3\lib\site-packages\IPython\utils\_process_win32.py:145: ResourceWarning: unclosed file <_io.BufferedReader name=6>

# %%
# !csvsql --db mysql://root:Akd!23456@localhost:3306/usanalysis --insert Users.csv
# Out:
# c:\users\anile\anaconda3\lib\site-packages\win32\lib\pywintypes.py:2: DeprecationWarning: the imp module is deprecated in favour of importlib; see the module's documentation for alternative uses
# c:\users\anile\anaconda3\lib\site-packages\agate\utils.py:285: UnnamedColumnWarning: Column 0 has no name. Using "a".
# C:\Users\anile\anaconda3\lib\site-packages\IPython\utils\_process_win32.py:145: ResourceWarning: unclosed file <_io.BufferedWriter name=4>
# C:\Users\anile\anaconda3\lib\site-packages\IPython\utils\_process_win32.py:145: ResourceWarning: unclosed file <_io.BufferedReader name=5>
# C:\Users\anile\anaconda3\lib\site-packages\IPython\utils\_process_win32.py:145: ResourceWarning: unclosed file <_io.BufferedReader name=6>

# %%
# Data succesfully loaded on Sql

# %%
#converting data into json file to upload in mongo db

# %%
orders_df.to_json(r'C:\Users\anile\orders.json')

# %%
return_df.to_json(r'C:\Users\anile\returns.json')

# %%
Users_df.to_json(r'C:\Users\anile\users.json')

# %%
# uploading the data to mongo db

# %%
client = pymongo.MongoClient("mongodb+srv://anildhiman31:Akd!23456@anil.27wwn.mongodb.net/?retryWrites=true&w=majority")
db = client.test

l = ['orders.json','returns.json','users.json']

for i in range(3):
    with open(r"C:\Users\anile\\"+l[i]) as file:
        data = [(json.load(file))]

    db = client['USA_Superstore']
    collection = db[l[i]]

    collection.insert_many(data)

# %%
# data was successfully loaded to mongoDB

# %%
#3 . Find out how much return that we have received and with a product id

# %%
orders_df.head()
# Out:
#    Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0   18606  Not Specified      0.01        2.88           0.50            2
# 1   20847           High      0.01        2.84           0.93            3
# 2   23086  Not Specified      0.03        6.68           6.15            3
# 3   23087  Not Specified      0.01        5.68           3.60            3
# 4   23088  Not Specified      0.00      205.99           2.50            3
#
#      Customer Name    Ship Mode Customer Segment Product Category  ...  \
# 0  Janice Fletcher  Regular Air        Corporate  Office Supplies  ...
# 1    Bonnie Potter  Express Air        Corporate  Office Supplies  ...
# 2    Bonnie Potter  Express Air        Corporate  Office Supplies  ...
# 3    Bonnie Potter  Regular Air        Corporate  Office Supplies  ...
# 4    Bonnie Potter  Express Air        Corporate       Technology  ...
#
#     Region State or Province       City  Postal Code Order Date  Ship Date  \
# ...

# %%
return_df
# Out:
#       Order ID    Status
# 0           65  Returned
# 1          612  Returned
# 2          614  Returned
# 3          678  Returned
# 4          710  Returned
# ...        ...       ...
# 1629    182681  Returned
# 1630    182683  Returned
# 1631    182750  Returned
# 1632    182781  Returned
# 1633    182906  Returned
#
# [1634 rows x 2 columns]

# %%
o = pd.DataFrame(orders_df[['Order ID','Product Name']])
r = pd.DataFrame(return_df['Order ID'])
pd.merge(o,r,on='Order ID')
# Out:
#     Order ID                                       Product Name
# 0       9895              Dixon My First Ticonderoga Pencil, #2
# 1      13959                                          Avery 493
# 2      13959                              EcoTones® Memo Sheets
# 3      36038                                          Newell 35
# 4      39490                  Staples SlimLine Pencil Sharpener
# ..       ...                                                ...
# 93      7107  Snap-A-Way® Black Print Carbonless Ruled Speed...
# 94      7107  Recycled Steel Personal File for Standard File...
# 95     42823                                         Xerox 1980
# 96     13638                                   TDK 4.7GB DVD+RW
# 97     47109                        SAFCO Folding Chair Trolley
#
# [98 rows x 2 columns]

# %%
#4 . try  to join order and return data both in sql and pandas

# %%
orders_df.merge(return_df,how='left',on='Order ID')
# Out:
#       Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0      18606  Not Specified      0.01        2.88           0.50            2
# 1      20847           High      0.01        2.84           0.93            3
# 2      23086  Not Specified      0.03        6.68           6.15            3
# 3      23087  Not Specified      0.01        5.68           3.60            3
# 4      23088  Not Specified      0.00      205.99           2.50            3
# ...      ...            ...       ...         ...            ...          ...
# 9421   20275       Critical      0.06       35.89          14.72         3402
# 9422   20276       Critical      0.00        3.34           7.49         3402
# 9423   24491  Not Specified      0.08      550.98          45.70         3402
# 9424   25914           High      0.10      105.98          13.99         3403
# 9425   24492  Not Specified      0.09        7.78           2.50         3403
#
# ...

# %%
#5 . Try to find out how many unique customer that we have

# %%
orders_df['Customer Name'].unique()
# Out:
# array(['Janice Fletcher', 'Bonnie Potter', 'Ronnie Proctor', ...,
#        'Florence Gold', 'Frederick Cole', 'Tammy Buckley'], dtype=object)

# %%
#6 . try to find out in how many regions we are selling a product and who is a manager for a respective region

# %%
o = pd.DataFrame(orders_df[['Region','Product Name']])
r = pd.DataFrame(Users_df[['Region','Manager']])
pd.merge(o,r,on='Region')
# Out:
#        Region                                       Product Name Manager
# 0     Central                                           Avery 49   Chris
# 1     Central  Howard Miller 12-3/4 Diameter Accuwave DS ™ Wa...   Chris
# 2     Central                                         Newell 321   Chris
# 3     Central                                         Newell 351   Chris
# 4     Central           OIC Colored Binder Clips, Assorted Sizes   Chris
# ...       ...                                                ...     ...
# 9421    South           Staples Copy Paper (20Lb. and 84 Bright)     Sam
# 9422    South            O'Sullivan 3-Shelf Heavy-Duty Bookcases     Sam
# 9423    South                  Logitech Cordless Access Keyboard     Sam
# 9424    South                      Contemporary Wood/Metal Frame     Sam
# 9425    South  Universal Premium White Copier/Laser Paper (20...     Sam
#
# [9426 rows x 3 columns]

# %%
#7 . find out how many different differnet shipement mode that we have and
#what is a percentage usablity of all the shipment mode with respect to dataset

# %%
orders_df['Usage_percent'] = orders_df['Order ID'] / orders_df.groupby('Ship Mode')['Order ID'].transform('sum')

# %%
orders_df
# Out:
#       Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0      18606  Not Specified      0.01        2.88           0.50            2
# 1      20847           High      0.01        2.84           0.93            3
# 2      23086  Not Specified      0.03        6.68           6.15            3
# 3      23087  Not Specified      0.01        5.68           3.60            3
# 4      23088  Not Specified      0.00      205.99           2.50            3
# ...      ...            ...       ...         ...            ...          ...
# 9421   20275       Critical      0.06       35.89          14.72         3402
# 9422   20276       Critical      0.00        3.34           7.49         3402
# 9423   24491  Not Specified      0.08      550.98          45.70         3402
# 9424   25914           High      0.10      105.98          13.99         3403
# 9425   24492  Not Specified      0.09        7.78           2.50         3403
#
# ...

# %%
#8 . Create a new coulmn and try to find our a diffrence between order date and shipment date

# %%
orders_df['Duration']= orders_df['Ship Date'] - orders_df['Order Date']

# %%
orders_df
# Out:
#       Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0      18606  Not Specified      0.01        2.88           0.50            2
# 1      20847           High      0.01        2.84           0.93            3
# 2      23086  Not Specified      0.03        6.68           6.15            3
# 3      23087  Not Specified      0.01        5.68           3.60            3
# 4      23088  Not Specified      0.00      205.99           2.50            3
# ...      ...            ...       ...         ...            ...          ...
# 9421   20275       Critical      0.06       35.89          14.72         3402
# 9422   20276       Critical      0.00        3.34           7.49         3402
# 9423   24491  Not Specified      0.08      550.98          45.70         3402
# 9424   25914           High      0.10      105.98          13.99         3403
# 9425   24492  Not Specified      0.09        7.78           2.50         3403
#
# ...

# %%
#9 . base on question number 8 find out for which order id we have shipment duration more than 10 days

# %%
orders_df[orders_df['Duration']> '10days'][['Order ID','Duration']].sort_values(by='Duration', ascending= True)
# Out:
#       Order ID Duration
# 1548     86318  11 days
# 1679     87957  11 days
# 1698     19556  11 days
# 5548     88223  14 days
# 1549     86318  15 days
# 5673     88352  17 days
# 1678     87957  17 days
# 1697     19556  17 days
# 8609     86436  17 days
# 8607     86434  18 days
# 8610     86436  19 days
# 8993     19841  19 days
# 8973     87300  19 days
# 5859     87572  22 days
# 5881     91294  24 days
# 8996     87300  27 days
# 8982     19841  27 days
# 1699     19556  28 days
# 1680     87957  28 days
# 8997     87300  31 days
# 8983     19841  31 days
# 643      87215  84 days
# 2515     86177  92 days

# %%
#10.Try to find out a list of a returned order which shipment duration was more then 15 days and find out 
#that region manager as well

# %%
returned_order_df = orders_df[['Order ID','Duration']]
merged_returned_df = pd.merge(returned_order_df,return_df, how='right', on='Order ID')
#merged_returned_df
merged_returned_df[merged_returned_df['Duration']> '15 days']['Order ID']
# Out:
# Series([], Name: Order ID, dtype: int64)

# %%
# could not find any orders with duration more than 15 days

# %%
#11. Gorup by region and find out which region is more profitable

# %%
orders_df.groupby('Region')['Profit'].sum().reset_index(name= 'Profit')
# Out:
#     Region         Profit
# 0  Central  519825.567067
# 1     East  377566.186045
# 2    South  104201.192420
# 3     West  310849.453897

# %%
#12 . Try to find out overalll in which country we are giving more discount

# %%
orders_df.groupby('State or Province')['Discount'].sum().sort_values(ascending = False).reset_index(name= 'Discount').head(1)
# Out:
#   State or Province  Discount
# 0        California     52.28

# %%
#13 . Give me a list of unique postal code

# %%
orders_df['Postal Code'].unique()
# Out:
# array([60101, 98221, 91776, ..., 61832, 62521, 26554], dtype=int64)

# %%
#14 . which customer segement is more profitalble find it out .

# %%
orders_df.groupby('Customer Segment')['Profit'].sum().sort_values(ascending= False)
# Out:
# Customer Segment
# Corporate         505538.627783
# Small Business    316474.592482
# Home Office       283869.553814
# Consumer          206559.625348
# Name: Profit, dtype: float64

# %%
#Coporate Segment is more profitable

# %%
#15 . try to find out the 10th most loss making product catagory .

# %%
loss_df = orders_df.groupby('Product Sub-Category')['Profit'].sum().sort_values(ascending = True).reset_index(name= 'Profit')
loss_df.loc[8]
# Out:
# Product Sub-Category      Envelopes
# Profit                  46133.22384
# Name: 8, dtype: object

# %%
#16 . Try to find out 10 top  product with highest margin

# %%
orders_df.groupby('Product Name')['Product Base Margin'].max().sort_values(ascending=False).reset_index(name='base margin').head(10)
# Out:
#                                         Product Name  base margin
# 0  Office Impressions Heavy Duty Welded Shelving ...         0.85
# 1                                         Accessory4         0.85
# 2                  Sterling Rubber Bands by Alliance         0.85
# 3                   Belkin OmniView SE Rackmount Kit         0.85
# 4                                        Accessory27         0.85
# 5  Serrated Blade or Curved Handle Hand Letter Op...         0.84
# 6  Tennsco Stur-D-Stor Boltless Shelving, 5 Shelv...         0.84
# 7                        Tennsco Commercial Shelving         0.84
# 8            Carina 42"Hx23 3/4"W Media Storage Unit         0.83
# 9                                        Accessory29         0.83
